# %% [markdown]
# # ML OPS Project
# In this notebook, I have prepared a model based on the Brazilian E-commerce dataset(https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce)
# I have prepared a custom dataset combing various features

# %%
#Unzip the dataset, one time thing
path_to_zip_file = r'C:\Users\vansh\AI and ML reading material\MLOps\OLips Customer Satisfaction Project\customer-satisfaction-mlops-main.zip'
directory_to_extract_to = r'C:\Users\vansh\AI and ML reading material\MLOps\OLips Customer Satisfaction Project'
import zipfile
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
import zenml
# !zenml init
# Out:
# Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.
# Initializing the ZenML global configuration version to 0.56.1
# ⠋ Initializing ZenML repository at c:\Users\vansh\AI and ML reading
# material\MLOps\OLips Customer Satisfaction Project.
# Creating database tables
#
# ⠙ Initializing ZenML repository at c:\Users\vansh\AI and ML reading
# material\MLOps\OLips Customer Satisfaction Project.
#
# ⠸ Initializing ZenML repository at c:\Users\vansh\AI and ML reading
# material\MLOps\OLips Customer Satisfaction Project.
#
# ⠼ Initializing ZenML repository at c:\Users\vansh\AI and ML reading
# material\MLOps\OLips Customer Satisfaction Project.
#
# ⠴ Initializing ZenML repository at c:\Users\vansh\AI and ML reading
# material\MLOps\OLips Customer Satisfaction Project.
#
# ⠧ Initializing ZenML repository at c:\Users\vansh\AI and ML reading
# material\MLOps\OLips Customer Satisfaction Project.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#read the csv file into a pandas dataframe
filepath = r'C:\Users\vansh\AI and ML reading material\MLOps\OLips Customer Satisfaction Project\data\olist_customers_dataset.csv'
df = pd.read_csv(filepath_or_buffer=filepath)
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4  0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2017-08-15 18:29:31  2017-08-15 20:05:16
# 4    delivered      2017-08-02 18:24:47  2017-08-02 18:43:15
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Let's do a little analysis of the dataframe

# %%
print("The different features are:")
for columns in df.columns:
    print(columns)
# Out:
# The different features are:
# order_id
# customer_id
# order_status
# order_purchase_timestamp
# order_approved_at
# order_delivered_carrier_date
# order_delivered_customer_date
# order_estimated_delivery_date
# payment_sequential
# payment_type
# payment_installments
# payment_value
# customer_unique_id
# customer_zip_code_prefix
# customer_city
# customer_state
# order_item_id
# product_id
# seller_id
# shipping_limit_date
# price
# freight_value
# product_category_name
# product_name_lenght
# product_description_lenght
# product_photos_qty
# product_weight_g
# product_length_cm
# product_height_cm
# product_width_cm
# product_category_name_english
# review_score
# review_comment_message
